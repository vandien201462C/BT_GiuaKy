# %% [markdown]
# <a href="https://colab.research.google.com/github/vandien201462C/BT_GiuaKy/blob/main/Flowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nhận diện 5 loài hoa
# PHAM VAN DIEN - 20146485

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/AI/Flowers/All Flower/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('dandelion'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sunflower'):
    output = 4.0
  if file.startswith('tulip'):
    output = 5.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (4317, 100, 100, 3) (4317,)

# %%
photos = photos.astype('float32')/255.0

print(photos.shape)
# Out:
# (4317, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (2589, 100, 100, 3)
# (2589,)
# (864, 100, 100, 3)
# (864,)
# (864, 100, 100, 3)
# (864,)

# %%
image_test=32
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hoa này là: ', trainY[image_test])
# Out:
# Hoa này là:  1.0

# %%
for i in range(25):  # 25 hình ảnh
  plt.subplot(5,5,i+1) # 5 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
 #one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (2589, 6)
# (864, 6)
# (864, 6)

# %%
batch_size=32
epochs=50
classes = 6

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))
     
# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2,863,046
# Trainable params: 2,863,046
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 81/81 [==============================] - 73s 898ms/step - loss: 1.2990 - accuracy: 0.4639 - val_loss: 1.2090 - val_accuracy: 0.5127
# Epoch 2/50
# 81/81 [==============================] - 74s 917ms/step - loss: 1.0053 - accuracy: 0.5890 - val_loss: 1.0358 - val_accuracy: 0.5914
# Epoch 3/50
# 81/81 [==============================] - 68s 843ms/step - loss: 0.8082 - accuracy: 0.6906 - val_loss: 1.0046 - val_accuracy: 0.6123
# Epoch 4/50
# 81/81 [==============================] - 77s 956ms/step - loss: 0.6475 - accuracy: 0.7520 - val_loss: 0.9299 - val_accuracy: 0.6169
# Epoch 5/50
# 81/81 [==============================] - 71s 878ms/step - loss: 0.4700 - accuracy: 0.8389 - val_loss: 1.0325 - val_accuracy: 0.6389
# Epoch 6/50
# 81/81 [==============================] - 80s 982ms/step - loss: 0.2917 - accuracy: 0.8949 - val_loss: 1.2074 - val_accuracy: 0.6076
# Epoch 7/50
# 81/81 [==============================] - 75s 934ms/step - loss: 0.1723 - accuracy: 0.9417 - val_loss: 1.3982 - val_accuracy: 0.6308
# Epoch 8/50
# 81/81 [==============================] - 74s 908ms/step - loss: 0.1014 - accuracy: 0.9676 - val_loss: 1.6064 - val_accuracy: 0.6192
# Epoch 9/50
# 81/81 [==============================] - 73s 906ms/step - loss: 0.0965 - accuracy: 0.9679 - val_loss: 1.8867 - val_accuracy: 0.6227
# Epoch 10/50
# 81/81 [==============================] - 75s 931ms/step - loss: 0.0526 - accuracy: 0.9861 - val_loss: 1.9991 - val_accuracy: 0.6366
# Epoch 11/50
# 81/81 [==============================] - 73s 903ms/step - loss: 0.0215 - accuracy: 0.9965 - val_loss: 2.0439 - val_accuracy: 0.6493
# Epoch 12/50
# 81/81 [==============================] - 75s 929ms/step - loss: 0.0055 - accuracy: 0.9996 - val_loss: 2.1267 - val_accuracy: 0.6470
# Epoch 13/50
# 81/81 [==============================] - 73s 904ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss:
# Epoch 36/50
# 81/81 [==============================] - 72s 894ms/step - loss: 3.4480e-05 - accuracy: 1.0000 - val_loss: 3.1090 - val_accuracy: 0.6481
# Epoch 37/50
# 81/81 [==============================] - 73s 902ms/step - loss: 3.1961e-05 - accuracy: 1.0000 - val_loss: 3.1292 - val_accuracy: 0.6493
# Epoch 38/50
# 81/81 [==============================] - 73s 904ms/step - loss: 2.9650e-05 - accuracy: 1.0000 - val_loss: 3.1505 - val_accuracy: 0.6505
# Epoch 39/50
# 81/81 [==============================] - 74s 914ms/step - loss: 2.7605e-05 - accuracy: 1.0000 - val_loss: 3.1713 - val_accuracy: 0.6516
# Epoch 40/50
# 81/81 [==============================] - 73s 906ms/step - loss: 2.5798e-05 - accuracy: 1.0000 - val_loss: 3.1902 - val_accuracy: 0.6516
# Epoch 41/50
# 81/81 [==============================] - 72s 889ms/step - loss: 2.4076e-05 - accuracy: 1.0000 - val_loss: 3.2089 - val_accuracy: 0.6516
# Epoch 42/50
# 81/81 [==============================] - 73s 903ms/step - loss: 2.2531e-05 - accuracy: 1.0000 - val_loss: 3.2277 - val_accuracy: 0.6505
# Epoch 43/50
# 81/81 [==============================] - 70s 870ms/step - loss: 2.1128e-05 - accuracy: 1.0000 - val_loss: 3.2473 - val_accuracy: 0.6505
# Epoch 44/50
# 81/81 [==============================] - 70s 857ms/step - loss: 1.9712e-05 - accuracy: 1.0000 - val_loss: 3.2652 - val_accuracy: 0.6528
# Epoch 45/50
# 81/81 [==============================] - 74s 917ms/step - loss: 1.8519e-05 - accuracy: 1.0000 - val_loss: 3.2838 - val_accuracy: 0.6528
# Epoch 46/50
# 81/81 [==============================] - 72s 895ms/step - loss: 1.7303e-05 - accuracy: 1.0000 - val_loss: 3.3013 - val_accuracy: 0.6528
# Epoch 47/50
# 81/81 [==============================] - 74s 912ms/step - loss: 1.6328e-05 - accuracy: 1.0000 - val_loss: 3.3200 - val_accuracy: 0.6528
# Epoch 48/50
# 81/81 [==============================] - 77s 960ms/step - loss: 1.5291e-05 - accuracy: 1.0000 - val_loss: 3.3373 - val_accuracy: 0.6516
# Epoch 49/50
# 81/81 [==============================] - 74s 911ms/step - loss: 1.4403e-05 - accuracy: 1.0000 - val_loss: 3.3549 - val_accuracy: 0.6516
# Epoch 50/50
# 81/81 [==============================] - 75s 929ms/step - loss: 1.3572e-05 - accuracy: 1.0000 - val_loss: 3.3725 - val_accuracy: 0.6528
# 3660.8580758571625

# %%
model.save('/content/drive/MyDrive/AI/Flower_model.H5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'daisy', 2:'dandelion',3:'rose',4:'sunflower',5:'tulip'}  
#test
filePath = '/content/drive/MyDrive/AI/Flowers/All Flower/daisy (25).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 149ms/step
# Predicted:  daisy

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=100, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 4/4 [==============================] - 3s 646ms/step
# Accuracy: 57.99999999999999 %
