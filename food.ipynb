# %% [markdown]
# <a href="https://colab.research.google.com/github/vandien201462C/BT_GiuaKy/blob/main/food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nhận diện 10 món ăn Việt Nam
# PHAM VAN DIEN - 20146485

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/AI/Data_Food_VN/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('BanhCuon'):
    output = 1.0
  if file.startswith('BanhGio'):
    output = 2.0
  if file.startswith('BanhMi'):
    output = 3.0
  if file.startswith('BanhPia'):
    output = 4.0
  if file.startswith('BunBoHue'):
    output = 5.0
  if file.startswith('BunRieu'):
    output = 6.0
  if file.startswith('CaKhoTo'):
    output = 7.0
  if file.startswith('ChaoLong'):
    output = 8.0
  if file.startswith('ComTam'):
    output = 9.0
  if file.startswith('NemChua'):
    output = 10.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (1553, 100, 100, 3) (1553,)

# %%
photos = photos.astype('float32')/255.0
print(photos.shape)
# Out:
# (1553, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)

(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (931, 100, 100, 3)
# (931,)
# (311, 100, 100, 3)
# (311,)
# (311, 100, 100, 3)
# (311,)

# %%
image_test=5
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Mon này là: ', trainY[image_test])
# Out:
# Mon này là:  4.0

# %%
for i in range(30):  # 30 hình ảnh
  plt.subplot(5,6,i+1) # 6 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
#one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (931, 11)
# (311, 11)
# (311, 11)

# %%
batch_size=32
epochs = 50
classes = 11

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'tanh', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))




# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'tanh'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 2,863,691
# Trainable params: 2,863,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=50,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 35s 1s/step - loss: 2.1734 - accuracy: 0.2148 - val_loss: 1.9561 - val_accuracy: 0.3119
# Epoch 2/50
# 30/30 [==============================] - 33s 1s/step - loss: 1.7597 - accuracy: 0.3663 - val_loss: 2.0676 - val_accuracy: 0.3280
# Epoch 3/50
# 30/30 [==============================] - 33s 1s/step - loss: 1.5282 - accuracy: 0.4941 - val_loss: 1.7017 - val_accuracy: 0.4084
# Epoch 4/50
# 30/30 [==============================] - 31s 1s/step - loss: 1.2921 - accuracy: 0.5832 - val_loss: 1.5011 - val_accuracy: 0.5048
# Epoch 5/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.9824 - accuracy: 0.6917 - val_loss: 1.4610 - val_accuracy: 0.5338
# Epoch 6/50
# 30/30 [==============================] - 39s 1s/step - loss: 0.7613 - accuracy: 0.7820 - val_loss: 1.4991 - val_accuracy: 0.4984
# Epoch 7/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.5481 - accuracy: 0.8754 - val_loss: 1.4761 - val_accuracy: 0.5402
# Epoch 8/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.3845 - accuracy: 0.9345 - val_loss: 1.5015 - val_accuracy: 0.5080
# Epoch 9/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.2411 - accuracy: 0.9753 - val_loss: 1.4137 - val_accuracy: 0.5402
# Epoch 10/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.1382 - accuracy: 0.9946 - val_loss: 1.4330 - val_accuracy: 0.5659
# Epoch 11/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0897 - accuracy: 0.9989 - val_loss: 1.4777 - val_accuracy: 0.5466
# Epoch 12/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0652 - accuracy: 0.9989 - val_loss: 1.4623 - val_accuracy: 0.5723
# Epoch 13/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 1.4800 - val_accuracy: 0.5788
# Epoch 14/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0397 - accuracy: 1.0000 - val_loss: 1.5042 - val_accuracy: 0.5788
# Epoch 15/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.5272 - val_accuracy: 0.5723
# Epoch 16/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 1.5294 - val_accuracy: 0.5659
# Epoch 17/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 1.5438 - val_accuracy: 0.5627
# Epoch 18/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 1.5499 - val_accuracy: 0.5691
# Epoch 19/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.5760 - val_accuracy: 0.5659
# Epoch 20/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.5668 - val_accuracy: 0.5659
# Epoch 21/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.5791 - val_accuracy: 0.5563
# Epoch 22/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.5910 - val_accuracy: 0.5595
# Epoch 23/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.5979 - val_accuracy: 0.5531
# Epoch 24/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.6038 - val_accuracy: 0.5595
# Epoch 25/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.6056 - val_accuracy: 0.5627
# Epoch 26/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.6270 - val_accuracy: 0.5563
# Epoch 27/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.6268 - val_accuracy: 0.5627
# Epoch 28/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.6464 - val_accuracy: 0.5498
# Epoch 29/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.6420 - val_accuracy: 0.5531
# Epoch 30/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.6595 - val_accuracy: 0.5466
# Epoch 31/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.6707 - val_accuracy: 0.5563
# Epoch 32/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.6775 - val_accuracy: 0.5563
# Epoch 33/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.6791 - val_accuracy: 0.5563
# Epoch 34/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.6851 - val_accuracy: 0.5531
# Epoch 35/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.6970 - val_accuracy: 0.5627
# Epoch 36/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7069 - val_accuracy: 0.5531
# Epoch 37/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.7093 - val_accuracy: 0.5498
# Epoch 38/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.7149 - val_accuracy: 0.5531
# Epoch 39/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7273 - val_accuracy: 0.5531
# Epoch 40/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7264 - val_accuracy: 0.5563
# Epoch 41/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7341 - val_accuracy: 0.5659
# Epoch 42/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.7244 - val_accuracy: 0.5498
# Epoch 43/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.7497 - val_accuracy: 0.5531
# Epoch 44/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.7533 - val_accuracy: 0.5498
# Epoch 45/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.7470 - val_accuracy: 0.5563
# Epoch 46/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.7580 - val_accuracy: 0.5498
# Epoch 47/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.7571 - val_accuracy: 0.5498
# Epoch 48/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.7731 - val_accuracy: 0.5563
# Epoch 49/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.7797 - val_accuracy: 0.5563
# Epoch 50/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.7766 - val_accuracy: 0.5466
# 1606.657769203186

# %%
model.save('/content/drive/MyDrive/AI/food_model.H5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'BanhCuon', 2:'BanhGio',3:'BanhMi',4:'BanhPia',5:'BunBoHue',6:'BunRieu',7:'CaKhoTo',8:'ChaoLong',9:'ComTam',10:'NemChua'}  
#test
filePath = '/content/drive/MyDrive/AI/Data_Food_VN/BanhCuon (100).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 407ms/step
# Predicted:  ChaoLong

# %%
name= {1:'BanhCuon', 2:'BanhGio',3:'BanhMi',4:'BanhPia',5:'BunBoHue',6:'BunRieu',7:'CaKhoTo',8:'ChaoLong',9:'ComTam',10:'NemChua'}  
#test
filePath = '/content/drive/MyDrive/AI/Data_Food_VN/BanhGio (57).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Predicted:  BanhGio

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=100, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 4/4 [==============================] - 2s 347ms/step
# Accuracy: 57.99999999999999 %
